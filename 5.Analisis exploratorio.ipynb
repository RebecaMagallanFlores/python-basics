# %% [markdown]
# # <span style='color:white'> <center>Manejo de datos con Pandas</center> </span>
# ## 1. Análisis Exploratorio
# <p><img src="https://online.york.ac.uk/wp-content/uploads/2021/07/man-in-a-suit-standing-behind-a-hologram-of-data-analytics-1030x579.jpg" width="750"</p>

# %% [markdown]
# ## Explorando un DataFrame
# <p>Cuando trabajamos con DataFrames, es un bueno comenzar por explorarlo y analizar su contenido.
#
# <code>homelessnes</code> es un dataset que contiene estimaciones de la falta de vivienda en cada estado de EE. UU. en 2018. La columna <code>individual</code> es el número de personas sin hogar que no forman parte de una familia con niños. La columna <code>family_members</code> es el número de personas sin hogar que forman parte de una familia con niños. La columna <code>state_pop</code> es la población total del estado. </p>

# %%
#Importar la libreria pandas
import pandas as pd

#Realizar la lectura del archivo csv homelessness
homelessness =pd.read_csv('C:\\Users\\rebec\\python-basics\\Data excel para manejo de librería Pandas\\homelessness.csv', 
    header=0,
    dtype={'region':'str'})

# %%
# Imprimir las primeras 5 lineas de mi DataFrame
display(homelessness)
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama         2570             864
# 1              Pacific                Alaska         1434             582
# 2             Mountain               Arizona         7259            2606
# 3   West South Central              Arkansas         2280             432
# 4              Pacific            California       109008           20964
# 5             Mountain              Colorado         7607            3250
# 6          New England           Connecticut         2280            1696
# 7       South Atlantic              Delaware          708             374
# 8       South Atlantic  District of Columbia         3770            3134
# 9       South Atlantic               Florida        21443            9587
# 10      South Atlantic               Georgia         6943            2556
# 11             Pacific                Hawaii         4131            2399
# ...

# %%
homelessness =pd.read_csv('C:\\Users\\rebec\\python-basics\\Data excel para manejo de librería Pandas\\homelessness.csv',
 header=0,
 usecols=['region','state'])

# %%
display(homelessness)
# Out:
#                 region                 state
# 0   East South Central               Alabama
# 1              Pacific                Alaska
# 2             Mountain               Arizona
# 3   West South Central              Arkansas
# 4              Pacific            California
# 5             Mountain              Colorado
# 6          New England           Connecticut
# 7       South Atlantic              Delaware
# 8       South Atlantic  District of Columbia
# 9       South Atlantic               Florida
# 10      South Atlantic               Georgia
# 11             Pacific                Hawaii
# 12            Mountain                 Idaho
# 13  East North Central              Illinois
# 14  East North Central               Indiana
# 15  West North Central                  Iowa
# 16  West North Central                Kansas
# 17  East South Central              Kentucky
# 18  West South Central             Louisiana
# 19         New England                 Maine
# ...

# %% [markdown]
# ##Imprimir todo el Data Frame

# %%
display(homelessness)
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama         2570             864
# 1              Pacific                Alaska         1434             582
# 2             Mountain               Arizona         7259            2606
# 3   West South Central              Arkansas         2280             432
# 4              Pacific            California       109008           20964
# 5             Mountain              Colorado         7607            3250
# 6          New England           Connecticut         2280            1696
# 7       South Atlantic              Delaware          708             374
# 8       South Atlantic  District of Columbia         3770            3134
# 9       South Atlantic               Florida        21443            9587
# 10      South Atlantic               Georgia         6943            2556
# 11             Pacific                Hawaii         4131            2399
# ...

# %%
##Imprimir las primeras 5 filas
display(homelessness.head(5))
# Out:
#                region       state  individuals  family_members  state_pop
# 0  East South Central     Alabama         2570             864    4887681
# 1             Pacific      Alaska         1434             582     735139
# 2            Mountain     Arizona         7259            2606    7158024
# 3  West South Central    Arkansas         2280             432    3009733
# 4             Pacific  California       109008           20964   39461588

# %%
##Imprimir las últimas 5 líneas de mi DataFrame
display(homelessness.tail(5))
# Out:
#                 region          state  individuals  family_members  state_pop
# 46      South Atlantic       Virginia         3928            2047    8501286
# 47             Pacific     Washington        16424            5880    7523869
# 48      South Atlantic  West Virginia         1021             222    1804291
# 49  East North Central      Wisconsin         2740            2167    5807406
# 50            Mountain        Wyoming          434             205     577601

# %%
##Imprimir 5 lineas aleatorias de mi DataFrame
display(homelessness.sample(5))
# Out:
#                 region       state  individuals  family_members  state_pop
# 31            Mountain  New Mexico         1949             602    2092741
# 15  West North Central        Iowa         1711            1038    3148618
# 12            Mountain       Idaho         1297             715    1750536
# 23  West North Central   Minnesota         3993            3250    5606249
# 37             Pacific      Oregon        11139            3337    4181886

# %%
# Imprimir la información de los campos de mi DataFrame
display(homelessness.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   region          51 non-null     str
#  1   state           51 non-null     str
#  2   individuals     51 non-null     int64
#  3   family_members  51 non-null     int64
#  4   state_pop       51 non-null     int64
# dtypes: int64(3), str(2)
# memory usage: 3.2 KB
# None

# %%
##Traerme filas específicas de mi Data Frame en este caso de la 10 a la 12
display(homelessness[10:13])
# Out:
#             region    state  individuals  family_members  state_pop
# 10  South Atlantic  Georgia         6943            2556   10511131
# 11         Pacific   Hawaii         4131            2399    1420593
# 12        Mountain    Idaho         1297             715    1750536

# %%
##Método para localizar una coordenada de mi DataFrame
homelessness.iloc[3,2]
# Out:
# np.int64(2280)

# %%
##Uso del iterador for para correr en un DataFrame de Pandas
for i in range (0,50):
    a = homelessness.iloc[i,2]
    calculo = a+ 10
    print(calculo)
# Out:
# 2580
# 1444
# 7269
# 2290
# 109018
# 7617
# 2290
# 718
# 3780
# 21453
# 6953
# 4141
# 1307
# 6762
# 3786
# 1721
# 1453
# 2745
# 2550
# 1460
# 4924
# 6821
# 5219
# 4003
# 1034
# 3786
# 993
# 1755
# 7068
# 845
# 6058
# 1959
# 39837
# 6461
# 477
# 6939
# 2833
# 11149
# 8173
# 757
# 3092
# 846
# 6149
# 19209
# 1914
# 790
# 3938
# 16434
# 1031
# 2750

# %%
##Conocer la longitud de alguna columna de mi DataFrame
len(homelessness['region'])
# Out:
# 51

# %%
# Imprimir el tamaño (#filas, #columnas) de mi DataFrame
homelessness.shape
# Out:
# (51, 5)

# %%
# Imprimir la estadística descriptiva básica de mi DataFrame
homelessness.describe()
# Out:
#          individuals  family_members     state_pop
# count      51.000000       51.000000  5.100000e+01
# mean     7225.784314     3504.882353  6.405637e+06
# std     15991.025083     7805.411811  7.327258e+06
# min       434.000000       75.000000  5.776010e+05
# 25%      1446.500000      592.000000  1.777414e+06
# 50%      3082.000000     1482.000000  4.461153e+06
# 75%      6781.500000     3196.000000  7.340946e+06
# max    109008.000000    52070.000000  3.946159e+07

# %% [markdown]
# ## Partes un DataFrame
# <p>Para comprender mejor la estructura de un DataFrame, es útil saber que constan de tres componentes, almacenados como atributos:
# <ul>
# <li><code>.values</code> muestra una matriz de valores NumPy bidimensional</li>
# <li><code>.columns</code> muestra índice de columnas: los nombres de las columnas.</li>
# <li><code>.index</code> muestra índice para las filas: números de fila o nombres de fila.</li>
# </ul>
# </p>

# %%
# Imprimir los valores de mi DataFrame
homelessness.values
# Out:
# array([['East South Central', 'Alabama', 2570, 864, 4887681],
#        ['Pacific', 'Alaska', 1434, 582, 735139],
#        ['Mountain', 'Arizona', 7259, 2606, 7158024],
#        ['West South Central', 'Arkansas', 2280, 432, 3009733],
#        ['Pacific', 'California', 109008, 20964, 39461588],
#        ['Mountain', 'Colorado', 7607, 3250, 5691287],
#        ['New England', 'Connecticut', 2280, 1696, 3571520],
#        ['South Atlantic', 'Delaware', 708, 374, 965479],
#        ['South Atlantic', 'District of Columbia', 3770, 3134, 701547],
#        ['South Atlantic', 'Florida', 21443, 9587, 21244317],
#        ['South Atlantic', 'Georgia', 6943, 2556, 10511131],
#        ['Pacific', 'Hawaii', 4131, 2399, 1420593],
#        ['Mountain', 'Idaho', 1297, 715, 1750536],
#        ['East North Central', 'Illinois', 6752, 3891, 12723071],
#        ['East North Central', 'Indiana', 3776, 1482, 6695497],
#        ['West North Central', 'Iowa', 1711, 1038, 3148618],
# ...

# %%
# Imprimir el nombre de mis campos (columnas) de mi DataFrame
homelessness.columns
# Out:
# Index(['region', 'state', 'individuals', 'family_members', 'state_pop'], dtype='str')

# %%
# Imprimir el indice de mi DataFrame
homelessness.index
# Out:
# RangeIndex(start=0, stop=51, step=1)

# %% [markdown]
# ## Ordenando filas de un DataFrame
# <p>Encontrar datos interesantes en un DataFrame suele ser más fácil si cambiamos el orden de las filas. Podemos ordenar las filas pasando un nombre de columna al método <code>.sort_values()</code>. </p>

# %%
# Ordena el DataFrame por la columna 'individual'
homelessness_ind= homelessness.sort_values(by='individuals', ascending=True)
# Imprime el resultado
display(homelessness_ind)
# Out:
#                 region                 state  individuals  family_members  \
# 50            Mountain               Wyoming          434             205
# 34  West North Central          North Dakota          467              75
# 7       South Atlantic              Delaware          708             374
# 39         New England          Rhode Island          747             354
# 45         New England               Vermont          780             511
# 29         New England         New Hampshire          835             615
# 41  West North Central          South Dakota          836             323
# 26            Mountain               Montana          983             422
# 48      South Atlantic         West Virginia         1021             222
# 24  East South Central           Mississippi         1024             328
# 12            Mountain                 Idaho         1297             715
# 1              Pacific                Alaska         1434             582
# ...

# %%
# Ordena el DataFrame por la columna 'family_members' de forma descendente
homelessness_fam= homelessness.sort_values(by='family_members',ascending=False)

# Imprime el resultado
display(homelessness_fam)
# Out:
#                 region                 state  individuals  family_members  \
# 32        Mid-Atlantic              New York        39827           52070
# 4              Pacific            California       109008           20964
# 21         New England         Massachusetts         6811           13257
# 9       South Atlantic               Florida        21443            9587
# 43  West South Central                 Texas        19199            6111
# 47             Pacific            Washington        16424            5880
# 38        Mid-Atlantic          Pennsylvania         8163            5349
# 13  East North Central              Illinois         6752            3891
# 30        Mid-Atlantic            New Jersey         6048            3350
# 37             Pacific                Oregon        11139            3337
# 35  East North Central                  Ohio         6929            3320
# 5             Mountain              Colorado         7607            3250
# ...

# %%
# Ordena el DataFrame por la columna 'region' y la columna 'state_pop' de manera descendente y ascendente respectivamente
homelessness_reg_state:state=homelessness.sort_values(by=['region','state'],ascending=[False,True])
# Imprime el resultado
display(homelessness_reg_state)
# Out:
#                 region                 state  individuals  family_members  \
# 3   West South Central              Arkansas         2280             432
# 18  West South Central             Louisiana         2540             519
# 36  West South Central              Oklahoma         2823            1048
# 43  West South Central                 Texas        19199            6111
# 15  West North Central                  Iowa         1711            1038
# 16  West North Central                Kansas         1443             773
# 23  West North Central             Minnesota         3993            3250
# 25  West North Central              Missouri         3776            2107
# 27  West North Central              Nebraska         1745             676
# 34  West North Central          North Dakota          467              75
# 41  West North Central          South Dakota          836             323
# 7       South Atlantic              Delaware          708             374
# ...

# %% [markdown]
# ## Seleccionando columnas de un DataFrame
# <p>Cuando trabajamos con datos, es posible que no necesitemos todas las variables en nuestro conjunto de datos. Los corchetes (<code>[]</code>) se pueden utilizar para seleccionar solo las columnas que nos interesan en un orden que nos resulte lógico... Para seleccionar solo la columna <code>"col_a"</code> de un DataFrame df, usaremos <code>df["col_a"]</code></p>

# %%
# Selecciona la columna 'individuals' 
Individuals=homelessness[['individuals','family_members']]
# Imprime el resultado
display(Individuals)
# Out:
#     individuals  family_members
# 0          2570             864
# 1          1434             582
# 2          7259            2606
# 3          2280             432
# 4        109008           20964
# 5          7607            3250
# 6          2280            1696
# 7           708             374
# 8          3770            3134
# 9         21443            9587
# 10         6943            2556
# 11         4131            2399
# 12         1297             715
# 13         6752            3891
# 14         3776            1482
# 15         1711            1038
# 16         1443             773
# 17         2735             953
# 18         2540             519
# 19         1450            1066
# 20         4914            2230
# 21         6811           13257
# 22         5209            3142
# 23         3993            3250
# 24         1024             328
# 25         3776            2107
# 26          983             422
# 27         1745             676
# ...

# %%
# Selecciona las columnas 'state' y 'family_members'
Individuals=homelessness[['individuals','family_members']]
# Imprime el resultado
display(Individuals)
# Out:
#     individuals  family_members
# 0          2570             864
# 1          1434             582
# 2          7259            2606
# 3          2280             432
# 4        109008           20964
# 5          7607            3250
# 6          2280            1696
# 7           708             374
# 8          3770            3134
# 9         21443            9587
# 10         6943            2556
# 11         4131            2399
# 12         1297             715
# 13         6752            3891
# 14         3776            1482
# 15         1711            1038
# 16         1443             773
# 17         2735             953
# 18         2540             519
# 19         1450            1066
# 20         4914            2230
# 21         6811           13257
# 22         5209            3142
# 23         3993            3250
# 24         1024             328
# 25         3776            2107
# 26          983             422
# 27         1745             676
# ...

# %%
# Selecciona las columnas 'region' y 'individuals' y de manera ascendente y descendente respectivamente
reg_ind = homelessness[['region','individuals']].sort_values(by=['region','individuals'], ascending=[True,False])
# Imprime el resultado
display(reg_ind)
# Out:
#                 region  individuals
# 35  East North Central         6929
# 13  East North Central         6752
# 22  East North Central         5209
# 14  East North Central         3776
# 49  East North Central         2740
# 42  East South Central         6139
# 17  East South Central         2735
# 0   East South Central         2570
# 24  East South Central         1024
# 32        Mid-Atlantic        39827
# 38        Mid-Atlantic         8163
# 30        Mid-Atlantic         6048
# 5             Mountain         7607
# 2             Mountain         7259
# 28            Mountain         7058
# 31            Mountain         1949
# 44            Mountain         1904
# 12            Mountain         1297
# 26            Mountain          983
# 50            Mountain          434
# 21         New England         6811
# 6          New England         2280
# 19         New England         1450
# 29         New England          835
# 45         New England          780
# ...

# %% [markdown]
# ## Filtrando un DataFrame
# <p>Una gran parte del proceso de análisis de datos consiste en encontrar qué partes de un conjunto de datos son interesantes. Una de las técnicas más simples para esto es encontrar un subconjunto de filas que coincida con algunos criterios. Esto a veces se conoce como <i>subsetting rows</i>.</p>

# %%
# Filtra las filas donde 'individuals' sea mayor a 10000
homelessness['individuals']>10000
# Resultado
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36    False
# 37     True
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44    False
# 45    False
# 46    False
# 47     True
# 48    False
# 49    False
# 50    False
# Name: individuals, dtype: bool

# %%
filtro = homelessness['individuals']>10000
ind_mayores_10K=homelessness[filtro]
display(ind_mayores_10K)
# Out:
#                 region       state  individuals  family_members  state_pop
# 4              Pacific  California       109008           20964   39461588
# 9       South Atlantic     Florida        21443            9587   21244317
# 32        Mid-Atlantic    New York        39827           52070   19530351
# 37             Pacific      Oregon        11139            3337    4181886
# 43  West South Central       Texas        19199            6111   28628666
# 47             Pacific  Washington        16424            5880    7523869

# %%
# Filra las filas donde 'region' es 'Mountain'
filtro = (homelessness['region']=='Mountain')
mountain_region=homelessness[filtro]
# Resultado
display(mountain_region)
# Out:
#       region       state  individuals  family_members  state_pop
# 2   Mountain     Arizona         7259            2606    7158024
# 5   Mountain    Colorado         7607            3250    5691287
# 12  Mountain       Idaho         1297             715    1750536
# 26  Mountain     Montana          983             422    1060665
# 28  Mountain      Nevada         7058             486    3027341
# 31  Mountain  New Mexico         1949             602    2092741
# 44  Mountain        Utah         1904             972    3153550
# 50  Mountain     Wyoming          434             205     577601

# %%
# Fltra las filas donde 'family_members' sea menor a '1000' y la region sea 'Pacific'
homelessness_family_region= (homelessness['family_members']<1000)&(homelessness['region']=='Pacific')
fam_reg_filtro=homelessness[homelessness_family_region]
# Resultado
display(fam_reg_filtro)
# Out:
#     region   state  individuals  family_members  state_pop
# 1  Pacific  Alaska         1434             582     735139

# %% [markdown]
# ## Filtrando variables categóricas
# <p>Filtrar un conjunto de datos basado en una variable categórica a menudo implica el uso del operador "o" (<code>|</code>) para seleccionar filas de varias categorías. Esto puede resultar tedioso cuando, por ejemplo, deseamos que una variable cumpla tres o más condiciones. Para esto, podemos utilizar el método <code>.isin()</code> que nos permitirá abordar este problema escribiendo una condición en lugar de tres o más por separado.</p>

# %%
# Filtra las filas que contengan las regiones South Atlantic o Mid-Atlantic
filtro = homelessness['region'].isin(['South Atlantic','Mid-Atlantic'])
# Resultado
filtro_variables= homelessness[filtro]
display(filtro_variables)
# Out:
#             region                 state  individuals  family_members  \
# 7   South Atlantic              Delaware          708             374
# 8   South Atlantic  District of Columbia         3770            3134
# 9   South Atlantic               Florida        21443            9587
# 10  South Atlantic               Georgia         6943            2556
# 20  South Atlantic              Maryland         4914            2230
# 30    Mid-Atlantic            New Jersey         6048            3350
# 32    Mid-Atlantic              New York        39827           52070
# 33  South Atlantic        North Carolina         6451            2817
# 38    Mid-Atlantic          Pennsylvania         8163            5349
# 40  South Atlantic        South Carolina         3082             851
# 46  South Atlantic              Virginia         3928            2047
# 48  South Atlantic         West Virginia         1021             222
#
#     state_pop
# 7      965479
# 8      701547
# ...

# %%
# Estados donde hay desiertos
Desiertos = ['California','Arizona','Nevada','Utah']
# Filtra las filas con los estados en donde hay desiertos
filtro= (homelessness['state'].isin(Desiertos))
filtro_homelessness= homelessness[filtro]
# Resultado
display(filtro_homelessness)
# Out:
#       region       state  individuals  family_members  state_pop
# 2   Mountain     Arizona         7259            2606    7158024
# 4    Pacific  California       109008           20964   39461588
# 28  Mountain      Nevada         7058             486    3027341
# 44  Mountain        Utah         1904             972    3153550

# %% [markdown]
# ## Agregando nuevas columnas
# <p>Por lo general los datos que tenemos no son suficientes para nuestro análisis, siempre necesitamos agregar nuevas columnas o campos calculados a nuestro DataFrame. Esto en el campo de la ciencia de datos se le conoce como <i>feature engineering</i>.
# Se pueden crear nuevas columnas desde cero, pero también es común derivarlas de otras, por ejemplo, agregando campos calculados con base en otro existente o cambiando su escala de unidades o valor.
#
# En este ejercicio, vamos a contestar la pregunta: "¿Qué estado tiene el mayor número de personas sin hogar por cada 10,000 personas?
# </p>

# %%
#Crear una columna nueva 
homelessness['columna nueva']=1
display(homelessness)
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama         2570             864
# 1              Pacific                Alaska         1434             582
# 2             Mountain               Arizona         7259            2606
# 3   West South Central              Arkansas         2280             432
# 4              Pacific            California       109008           20964
# 5             Mountain              Colorado         7607            3250
# 6          New England           Connecticut         2280            1696
# 7       South Atlantic              Delaware          708             374
# 8       South Atlantic  District of Columbia         3770            3134
# 9       South Atlantic               Florida        21443            9587
# 10      South Atlantic               Georgia         6943            2556
# 11             Pacific                Hawaii         4131            2399
# ...

# %%
# Agregamos una columna que tenga el total de columnas sin hogar
homelessness['total_homelessness'] = homelessness['individuals'] + homelessness['family_members']
display(homelessness)
# Crear una columna que calcule las personas sin hogar por cada 10K personas por estado
homelessness['indiv_per_20k']=homelessness['homelessness_per_capita']*10000
display(homelessness)
# Vamos a filtrar esta nueva columna 'indiv_per_20k' con valores mayores a 20
homelessness[homelessness['indiv_per_20k']>20]
display(homelessness)
# Resultado
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama         2570             864
# 1              Pacific                Alaska         1434             582
# 2             Mountain               Arizona         7259            2606
# 3   West South Central              Arkansas         2280             432
# 4              Pacific            California       109008           20964
# 5             Mountain              Colorado         7607            3250
# 6          New England           Connecticut         2280            1696
# 7       South Atlantic              Delaware          708             374
# 8       South Atlantic  District of Columbia         3770            3134
# 9       South Atlantic               Florida        21443            9587
# 10      South Atlantic               Georgia         6943            2556
# 11             Pacific                Hawaii         4131            2399
# ...

# %%
# Vamos a filtrar esta nueva columna 'indiv_per_20k' con valores mayores a 20
filtro = homelessness['indiv_per_20k']>20
homelessness_filtro= homelessness[filtro]
display(homelessness_filtro)
# Out:
#             region                 state  individuals  family_members  \
# 1          Pacific                Alaska         1434             582
# 4          Pacific            California       109008           20964
# 8   South Atlantic  District of Columbia         3770            3134
# 11         Pacific                Hawaii         4131            2399
# 21     New England         Massachusetts         6811           13257
# 28        Mountain                Nevada         7058             486
# 32    Mid-Atlantic              New York        39827           52070
# 37         Pacific                Oregon        11139            3337
# 45     New England               Vermont          780             511
# 47         Pacific            Washington        16424            5880
#
#     state_pop  columna nueva  total_homelessness  homelessness_per_capita  \
# 1      735139              1                2016                 0.002742
# ...

# %%
# Vamos a ordenar de mandera descendente nuestra nueva variable
homelessness_ordenada=homelessness.sort_values(by='indiv_per_20k',ascending=False)
display(homelessness_ordenada)
# Out:
#                 region                 state  individuals  family_members  \
# 8       South Atlantic  District of Columbia         3770            3134
# 32        Mid-Atlantic              New York        39827           52070
# 11             Pacific                Hawaii         4131            2399
# 37             Pacific                Oregon        11139            3337
# 4              Pacific            California       109008           20964
# 47             Pacific            Washington        16424            5880
# 21         New England         Massachusetts         6811           13257
# 1              Pacific                Alaska         1434             582
# 28            Mountain                Nevada         7058             486
# 45         New England               Vermont          780             511
# 5             Mountain              Colorado         7607            3250
# 19         New England                 Maine         1450            1066
# ...

# %%
# Agregamos columnas d epersonas sin hogar per capita
homelessness['homelessness_per_capita'] = homelessness['total_homelessness'] / homelessness['state_pop']

# %%
display(homelessness)
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama         2570             864
# 1              Pacific                Alaska         1434             582
# 2             Mountain               Arizona         7259            2606
# 3   West South Central              Arkansas         2280             432
# 4              Pacific            California       109008           20964
# 5             Mountain              Colorado         7607            3250
# 6          New England           Connecticut         2280            1696
# 7       South Atlantic              Delaware          708             374
# 8       South Atlantic  District of Columbia         3770            3134
# 9       South Atlantic               Florida        21443            9587
# 10      South Atlantic               Georgia         6943            2556
# 11             Pacific                Hawaii         4131            2399
# ...

# %%
# Vamos a seleccionar únicamente los campos 'state' y 'indiv_per_20k'
homelessness_filtro = homelessness_filtro[['state','indiv_per_20k']]
display(homelessness_filtro)
# Out:
#                    state  indiv_per_20k
# 1                 Alaska      27.423385
# 4             California      32.936333
# 8   District of Columbia      98.411083
# 11                Hawaii      45.966720
# 21         Massachusetts      29.157438
# 28                Nevada      24.919558
# 32              New York      47.053430
# 37                Oregon      34.615960
# 45               Vermont      20.677240
# 47            Washington      29.644323
